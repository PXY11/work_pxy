# %%
import pandas as pd
from matplotlib import pyplot as plt
import pickle

# %%
with open('../data/'+'df_indicator' + '.pkl', 'rb') as f:
    df_indicator = pickle.load(f)
df_indicator
# Out:
#                            bnb_slope     bnb_cci    bnb_mfi   bnb_adxr  \
# timestamp
# 2021-01-01 00:00:00+00:00        NaN         NaN        NaN        NaN
# 2021-01-01 00:15:00+00:00        NaN         NaN        NaN        NaN
# 2021-01-01 00:30:00+00:00        NaN         NaN        NaN        NaN
# 2021-01-01 00:45:00+00:00        NaN         NaN        NaN        NaN
# 2021-01-01 01:00:00+00:00        NaN         NaN        NaN        NaN
# ...                              ...         ...        ...        ...
# 2021-09-30 14:45:00+00:00   0.136594   73.411333  57.076077  12.730025
# 2021-09-30 15:00:00+00:00   0.142932   87.025785  56.502759  12.834692
# 2021-09-30 15:15:00+00:00   0.149183  106.618094  57.817144  12.917821
# 2021-09-30 15:30:00+00:00   0.152379  100.149457  58.923474  12.994032
# 2021-09-30 15:45:00+00:00   0.153795   84.110034  59.149837  13.056282
#
#                             bnb_atr    bnb_er  btc_slope    btc_cci  \
# timestamp
# ...

# %%
df_indicator.describe()
# Out:
#           bnb_slope       bnb_cci       bnb_mfi      bnb_adxr       bnb_atr  \
# count  26081.000000  26081.000000  26080.000000  25890.000000  24832.000000
# mean       0.012853     10.890955     51.449163     11.356278      3.308625
# std        0.284426    118.150786      7.377519      5.055455      1.746658
# min       -1.999459   -526.181608     26.837974      3.607051      0.329606
# 25%       -0.092491    -72.521737     46.291781      7.917936      2.386242
# 50%        0.009165     17.158844     51.313499     10.078164      2.959929
# 75%        0.128720     94.757941     56.727287     13.172597      4.228122
# max        1.447017    784.968523     75.254525     33.298759      7.276159
#
#              bnb_er     btc_slope       btc_cci       btc_mfi      btc_adxr  \
# count  24833.000000  26081.000000  26081.000000  26080.000000  25890.000000
# mean       0.333281      0.515844      4.498720     50.182861     11.823562
# ...

# %%
symbol_names = ['bnb','btc','eth','uni','link']
indicators = ['slope','cci','mfi','adxr','atr','er']

# %%
df_indicator['bnb_slope'].plot(title='bnb_slope',figsize=(18,3.5),kind='hist')
plt.show()
# df_indicator['btc_slope'].plot(title='btc_slope',figsize=(18,3.5),kind='hist')
# plt.show()
# df_indicator['eth_slope'].plot(title='eth_slope',figsize=(18,3.5),kind='hist')
# plt.show()
# df_indicator['uni_slope'].plot(title='uni_slope',figsize=(18,3.5),kind='hist')
# plt.show()
# df_indicator['link_slope'].plot(title='link_slope',figsize=(18,3.5),kind='hist')
# plt.show()

# %%
df_indicator['bnb_slope'].plot(title='bnb_slope',figsize=(18,3.5))
plt.show()
# df_indicator['btc_slope'].plot(title='btc_slope',figsize=(18,3.5))
# plt.show()
# df_indicator['eth_slope'].plot(title='eth_slope',figsize=(18,3.5))
# plt.show()
# df_indicator['uni_slope'].plot(title='uni_slope',figsize=(18,3.5))
# plt.show()
# df_indicator['link_slope'].plot(title='link_slope',figsize=(18,3.5))
# plt.show()

# %%
df_indicator['bnb_cci'].plot(title='bnb_cci',figsize=(18,3.5),kind='hist')
plt.show()
# df_indicator['btc_cci'].plot(title='btc_cci',figsize=(18,3.5),kind='hist')
# plt.show()
# df_indicator['eth_cci'].plot(title='eth_cci',figsize=(18,3.5),kind='hist')
# plt.show()
# df_indicator['uni_cci'].plot(title='uni_cci',figsize=(18,3.5),kind='hist')
# plt.show()
# df_indicator['link_cci'].plot(title='link_cci',figsize=(18,3.5),kind='hist')
# plt.show()

# %%
df_indicator['bnb_cci'].plot(title='bnb_cci',figsize=(18,3.5))
plt.show()
# df_indicator['btc_cci'].plot(title='btc_cci',figsize=(18,3.5))
# plt.show()
# df_indicator['eth_cci'].plot(title='eth_cci',figsize=(18,3.5))
# plt.show()
# df_indicator['uni_cci'].plot(title='uni_cci',figsize=(18,3.5))
# plt.show()
# df_indicator['link_cci'].plot(title='link_cci',figsize=(18,3.5))
# plt.show()

# %%
df_indicator['bnb_mfi'].plot(title='bnb_mfi',figsize=(18,3.5),kind='hist')
plt.show()
# df_indicator['btc_mfi'].plot(title='btc_mfi',figsize=(18,3.5))
# plt.show()
# df_indicator['eth_mfi'].plot(title='eth_mfi',figsize=(18,3.5))
# plt.show()
# df_indicator['uni_mfi'].plot(title='uni_mfi',figsize=(18,3.5))
# plt.show()
# df_indicator['link_mfi'].plot(title='link_mfi',figsize=(18,3.5))
# plt.show()

# %%
df_indicator['bnb_mfi'].plot(title='bnb_mfi',figsize=(18,3.5))
plt.show()
# df_indicator['btc_mfi'].plot(title='btc_mfi',figsize=(18,3.5))
# plt.show()
# df_indicator['eth_mfi'].plot(title='eth_mfi',figsize=(18,3.5))
# plt.show()
# df_indicator['uni_mfi'].plot(title='uni_mfi',figsize=(18,3.5))
# plt.show()
# df_indicator['link_mfi'].plot(title='link_mfi',figsize=(18,3.5))
# plt.show()

# %%
df_indicator['bnb_er'].plot(title='bnb_er',figsize=(18,3.5),kind='hist')
plt.show()
# df_indicator['btc_er'].plot(title='btc_er',figsize=(18,3.5))
# plt.show()
# df_indicator['eth_er'].plot(title='eth_er',figsize=(18,3.5))
# plt.show()
# df_indicator['uni_er'].plot(title='uni_er',figsize=(18,3.5))
# plt.show()
# df_indicator['link_er'].plot(title='link_er',figsize=(18,3.5))
# plt.show()

# %%
df_indicator['bnb_er'].plot(title='bnb_er',figsize=(18,3.5))
plt.show()
# df_indicator['btc_er'].plot(title='btc_er',figsize=(18,3.5))
# plt.show()
# df_indicator['eth_er'].plot(title='eth_er',figsize=(18,3.5))
# plt.show()
# df_indicator['uni_er'].plot(title='uni_er',figsize=(18,3.5))
# plt.show()
# df_indicator['link_er'].plot(title='link_er',figsize=(18,3.5))
# plt.show()
